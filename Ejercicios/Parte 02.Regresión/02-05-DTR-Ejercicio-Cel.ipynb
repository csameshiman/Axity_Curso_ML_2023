# %% [markdown]
# # Decision Trees - Ejercicio - Precio de Celulares

# %% [markdown]
# **Contexto**
# Este conjunto de datos contiene el precio de celulares, de acuerdo diversos factores.
#
# **Contenido**
# El conjunto de datos proviene de kaggle: [Mobile Price Prediction](https://www.kaggle.com/datasets/mohannapd/mobile-price-prediction).
# Contiene 161 renglones, con las siguientes columnas:
#
# | Variable     | Definición                     | Valor           |
# | ------------ | ------------------------------ | --------------- |
# | Product_id   | Identificador del celular      | Id numérico     |
# | Price        | Precio **(variable objetivo)** | USD             |
# | Sale         | Número de ticket               | Id numérico     |
# | weight       | Peso                           | Libras          |
# | resolution   | Resolución                     | Pulgadas        |
# | ppi          | Densidad                       | Pixeles         |
# | cpu core     | Núcleos de cpu                 | Numérico entero |
# | cpu freq     | Frecuencia del cpu             | GHz             |
# | internal mem | Memoria interna                | GB              |
# | ram          | Memoria RAM                    | GB              |
# | RearCam      | Cámaras traseras               | Numérico entero |
# | Front_Cam    | Cámaras delanteras             | Numérico entero |
# | battery      | Batería                        | mAh             |
# | thickness    | Ancho                          | Milímetros      |
#
# **Planteamiento del problema**
# Se busca encontrar que factores tienen mayor influencia en el precio de los celulares.

# %%
# Importar librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn import tree

# %% [markdown]
# ## Cargar Datos

# %%
# Importar los datos
df = pd.read_csv('Cellphone.csv')
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
# Renombrar columnas
df.columns = ['id_producto', 'precio', 'ticket', 'peso', 'resolución', 'densidad_pixel', 'nucleos_cpu',
              'frec_cpu', 'mem_interna', 'ram', 'camara_tras', 'camara_frontal', 'bateria', 'ancho']

# %% [markdown]
# ## Modelado

# %%
# Variables independientes
X = df[['peso', 'resolución', 'densidad_pixel', 'nucleos_cpu',
              'frec_cpu', 'mem_interna', 'ram', 'camara_tras', 'camara_frontal', 'bateria', 'ancho']]
X.head()
# Out:
#     peso  resolución  densidad_pixel  nucleos_cpu  frec_cpu  mem_interna  \
# 0  135.0         5.2             424            8      1.35         16.0
# 1  125.0         4.0             233            2      1.30          4.0
# 2  110.0         4.7             312            4      1.20          8.0
# 3  118.5         4.0             233            2      1.30          4.0
# 4  125.0         4.0             233            2      1.30          4.0
#
#      ram  camara_tras  camara_frontal  bateria  ancho
# 0  3.000        13.00             8.0     2610    7.4
# 1  1.000         3.15             0.0     1700    9.9
# 2  1.500        13.00             5.0     2000    7.6
# 3  0.512         3.15             0.0     1400   11.0
# 4  1.000         3.15             0.0     1700    9.9

# %%
# Variable dependiente
y = df['precio']
y.head()
# Out:
# 0    2357
# 1    1749
# 2    1916
# 3    1315
# 4    1749
# Name: precio, dtype: int64

# %%
print('X:', len(X), 'y:', len(y))
# Out:
# X: 161 y: 161

# %%
# Conjunto de entrenamiento y pruebas
## Escribe tu código aqui

# %%
print('X_train:', len(X_train), 'y_train:', len(y_train))
print('X_test:',  len(X_test),  'y_test:',  len(y_test))
# Out:
# X_train: 112 y_train: 112
# X_test: 49 y_test: 49

# %%
# Entrenamiento
## Escribe tu código aqui

# %%
# Out:
# DecisionTreeRegressor()

# %%
# Predicciones
## Escribe tu código aqui

# %%
# Out:
# array([3316.,  754., 1921., 2137., 2859., 2744., 2536., 3287., 1396.,
#         791., 2266., 1831., 2006., 2685., 3211., 1777., 1777., 2562.,
#        2744., 1646., 1989., 3658., 1741., 1315., 2044., 2654., 3055.,
#        3287., 1522., 2536., 2445., 1942., 1984., 2714., 1238., 2571.,
#        2744., 2258., 2824., 1612., 2044., 2977., 2323., 4361., 3316.,
#        2685., 2343., 2938., 1612.])

# %% [markdown]
# ## Evaluación

# %%
## Escribe tu código aqui

# %%
# Out:
# MAE: 112.0
# MSE: 47042.61224489796
# RMSE: 216.89308943555108
# R2: 0.9065756819377799

# %%
# Visualización de los resultados
text = tree.export_text(model)
print(text)
# Out:
# |--- feature_6 <= 1.75
# |   |--- feature_4 <= 0.60
# |   |   |--- feature_10 <= 13.65
# |   |   |   |--- feature_0 <= 78.15
# |   |   |   |   |--- feature_1 <= 1.95
# |   |   |   |   |   |--- value: [791.00]
# |   |   |   |   |--- feature_1 >  1.95
# |   |   |   |   |   |--- value: [754.00]
# |   |   |   |--- feature_0 >  78.15
# |   |   |   |   |--- value: [833.00]
# |   |   |--- feature_10 >  13.65
# |   |   |   |--- feature_0 <= 106.45
# |   |   |   |   |--- feature_9 <= 875.00
# |   |   |   |   |   |--- value: [614.00]
# |   |   |   |   |--- feature_9 >  875.00
# |   |   |   |   |   |--- value: [628.00]
# |   |   |   |--- feature_0 >  106.45
# |   |   |   |   |--- value: [705.00]
# |   |--- feature_4 >  0.60
# |   |   |--- feature_10 <= 8.45
# |   |   |   |--- feature_3 <= 6.00
# |   |   |   |   |--- feature_5 <= 12.00
# |   |   |   |   |   |--- feature_10 <= 8.25
# |   |   |   |   |   |   |--- feature_7 <= 10.50
# |   |   |   |   |   |   |   |--- feature_9 <= 2570.00
# |   |   |   |   |   |   |   |   |--- value: [1950.00]
# |   |   |   |   |   |   |   |--- feature_9 >  2570.00
# |   |   |   |   |   |   |   |   |--- value: [1984.00]
# |   |   |   |   |   |   |--- feature_7 >  10.50
# |   |   |   |   |   |   |   |--- feature_0 <= 144.50
# |   |   |   |   |   |   |   |   |--- value: [1916.00]
# |   |   |   |   |   |   |   |--- feature_0 >  144.50
# |   |   |   |   |   |   |   |   |--- value: [1921.00]
# |   |   |   |   |   |--- feature_10 >  8.25
# |   |   |   |   |   |   |--- value: [1831.00]
# |   |   |   |   |--- feature_5 >  12.00
# |   |   |   |   |   |--- value: [2174.00]
# |   |   |   |--- feature_3 >  6.00
# |   |   |   |   |--- feature_8 <= 6.50
# |   |   |   |   |   |--- value: [2323.00]
# |   |   |   |   |--- feature_8 >  6.50
# |   |   |   |   |   |--- value: [2266.00]
# |   |   |--- feature_10 >  8.45
# |   |   |   |--- feature_9 <= 1580.00
# |   |   |   |   |--- feature_4 <= 1.10
# |   |   |   |   |   |--- value: [1421.00]
# |   |   |   |   |--- feature_4 >  1.10
# |   |   |   |   |   |--- feature_9 <= 1530.00
# |   |   |   |   |   |   |--- feature_2 <= 234.00
# |   |   |   |   |   |   |   |--- value: [1315.00]
# |   |   |   |   |   |   |--- feature_2 >  234.00
# |   |   |   |   |   |   |   |--- value: [1302.00]
# |   |   |   |   |   |--- feature_9 >  1530.00
# |   |   |   |   |   |   |--- value: [1238.00]
# |   |   |   |--- feature_9 >  1580.00
# |   |   |   |   |--- feature_4 <= 1.25
# |   |   |   |   |   |--- feature_5 <= 12.00
# |   |   |   |   |   |   |--- feature_2 <= 233.00
# |   |   |   |   |   |   |   |--- feature_2 <= 165.00
# |   |   |   |   |   |   |   |   |--- value: [1646.00]
# |   |   |   |   |   |   |   |--- feature_2 >  165.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 140.00
# |   |   |   |   |   |   |   |   |   |--- value: [1511.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  140.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [1522.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [1357.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_2 >  233.00
# |   |   |   |   |   |   |   |--- feature_8 <= 0.60
# |   |   |   |   |   |   |   |   |--- feature_0 <= 136.50
# |   |   |   |   |   |   |   |   |   |--- value: [1734.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  136.50
# |   |   |   |   |   |   |   |   |   |--- value: [1741.00]
# |   |   |   |   |   |   |   |--- feature_8 >  0.60
# |   |   |   |   |   |   |   |   |--- value: [1612.00]
# |   |   |   |   |   |--- feature_5 >  12.00
# |   |   |   |   |   |   |--- feature_6 <= 1.25
# |   |   |   |   |   |   |   |--- value: [1676.00]
# |   |   |   |   |   |   |--- feature_6 >  1.25
# |   |   |   |   |   |   |   |--- value: [1810.00]
# |   |   |   |   |--- feature_4 >  1.25
# |   |   |   |   |   |--- feature_4 <= 1.35
# |   |   |   |   |   |   |--- feature_10 <= 10.00
# |   |   |   |   |   |   |   |--- feature_10 <= 9.55
# |   |   |   |   |   |   |   |   |--- value: [1777.00]
# |   |   |   |   |   |   |   |--- feature_10 >  9.55
# |   |   |   |   |   |   |   |   |--- value: [1749.00]
# |   |   |   |   |   |   |--- feature_10 >  10.00
# |   |   |   |   |   |   |   |--- value: [1843.00]
# |   |   |   |   |   |--- feature_4 >  1.35
# |   |   |   |   |   |   |--- value: [2006.00]
# |--- feature_6 >  1.75
# |   |--- feature_6 <= 3.50
# |   |   |--- feature_10 <= 7.10
# |   |   |   |--- feature_2 <= 414.50
# |   |   |   |   |--- feature_9 <= 2150.00
# |   |   |   |   |   |--- value: [2571.00]
# |   |   |   |   |--- feature_9 >  2150.00
# |   |   |   |   |   |--- feature_7 <= 14.50
# |   |   |   |   |   |   |--- value: [2714.00]
# |   |   |   |   |   |--- feature_7 >  14.50
# |   |   |   |   |   |   |--- value: [2654.00]
# |   |   |   |--- feature_2 >  414.50
# |   |   |   |   |--- value: [3316.00]
# |   |   |--- feature_10 >  7.10
# |   |   |   |--- feature_9 <= 2550.00
# |   |   |   |   |--- feature_0 <= 123.50
# |   |   |   |   |   |--- value: [2276.00]
# |   |   |   |   |--- feature_0 >  123.50
# |   |   |   |   |   |--- feature_0 <= 143.10
# |   |   |   |   |   |   |--- feature_0 <= 135.10
# |   |   |   |   |   |   |   |--- value: [1989.00]
# |   |   |   |   |   |   |--- feature_0 >  135.10
# |   |   |   |   |   |   |   |--- value: [1942.00]
# |   |   |   |   |   |--- feature_0 >  143.10
# |   |   |   |   |   |   |--- feature_8 <= 3.50
# |   |   |   |   |   |   |   |--- value: [2258.00]
# |   |   |   |   |   |   |--- feature_8 >  3.50
# |   |   |   |   |   |   |   |--- feature_8 <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [2087.00]
# |   |   |   |   |   |   |   |--- feature_8 >  6.50
# |   |   |   |   |   |   |   |   |--- value: [2137.00]
# |   |   |   |--- feature_9 >  2550.00
# |   |   |   |   |--- feature_9 <= 3565.00
# |   |   |   |   |   |--- feature_1 <= 5.35
# |   |   |   |   |   |   |--- feature_4 <= 1.30
# |   |   |   |   |   |   |   |--- value: [2744.00]
# |   |   |   |   |   |   |--- feature_4 >  1.30
# |   |   |   |   |   |   |   |--- feature_4 <= 2.40
# |   |   |   |   |   |   |   |   |--- feature_0 <= 141.00
# |   |   |   |   |   |   |   |   |   |--- value: [2357.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  141.00
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 8.55
# |   |   |   |   |   |   |   |   |   |   |--- value: [2392.00]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  8.55
# |   |   |   |   |   |   |   |   |   |   |--- value: [2409.00]
# |   |   |   |   |   |   |   |--- feature_4 >  2.40
# |   |   |   |   |   |   |   |   |--- feature_10 <= 8.50
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 7.70
# |   |   |   |   |   |   |   |   |   |   |--- value: [2508.00]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  7.70
# |   |   |   |   |   |   |   |   |   |   |--- value: [2580.00]
# |   |   |   |   |   |   |   |   |--- feature_10 >  8.50
# |   |   |   |   |   |   |   |   |   |--- value: [2343.00]
# |   |   |   |   |   |--- feature_1 >  5.35
# |   |   |   |   |   |   |--- feature_5 <= 24.00
# |   |   |   |   |   |   |   |--- feature_0 <= 194.50
# |   |   |   |   |   |   |   |   |--- value: [2562.00]
# |   |   |   |   |   |   |   |--- feature_0 >  194.50
# |   |   |   |   |   |   |   |   |--- value: [2536.00]
# |   |   |   |   |   |   |--- feature_5 >  24.00
# |   |   |   |   |   |   |   |--- feature_4 <= 1.66
# |   |   |   |   |   |   |   |   |--- value: [2824.00]
# |   |   |   |   |   |   |   |--- feature_4 >  1.66
# |   |   |   |   |   |   |   |   |--- feature_4 <= 2.25
# |   |   |   |   |   |   |   |   |   |--- value: [2685.00]
# |   |   |   |   |   |   |   |   |--- feature_4 >  2.25
# |   |   |   |   |   |   |   |   |   |--- value: [2744.00]
# |   |   |   |   |--- feature_9 >  3565.00
# |   |   |   |   |   |--- feature_6 <= 2.50
# |   |   |   |   |   |   |--- feature_1 <= 6.75
# |   |   |   |   |   |   |   |--- value: [2054.00]
# |   |   |   |   |   |   |--- feature_1 >  6.75
# |   |   |   |   |   |   |   |--- value: [2044.00]
# |   |   |   |   |   |--- feature_6 >  2.50
# |   |   |   |   |   |   |--- feature_1 <= 8.60
# |   |   |   |   |   |   |   |--- value: [2445.00]
# |   |   |   |   |   |   |--- feature_1 >  8.60
# |   |   |   |   |   |   |   |--- value: [2491.00]
# |   |--- feature_6 >  3.50
# |   |   |--- feature_6 <= 5.00
# |   |   |   |--- feature_2 <= 339.00
# |   |   |   |   |--- value: [2438.00]
# |   |   |   |--- feature_2 >  339.00
# |   |   |   |   |--- feature_2 <= 416.50
# |   |   |   |   |   |--- feature_4 <= 1.75
# |   |   |   |   |   |   |--- value: [3116.00]
# |   |   |   |   |   |--- feature_4 >  1.75
# |   |   |   |   |   |   |--- feature_10 <= 7.40
# |   |   |   |   |   |   |   |--- value: [3260.00]
# |   |   |   |   |   |   |--- feature_10 >  7.40
# |   |   |   |   |   |   |   |--- value: [3287.00]
# |   |   |   |   |--- feature_2 >  416.50
# |   |   |   |   |   |--- feature_9 <= 3100.00
# |   |   |   |   |   |   |--- feature_7 <= 14.00
# |   |   |   |   |   |   |   |--- value: [2977.00]
# |   |   |   |   |   |   |--- feature_7 >  14.00
# |   |   |   |   |   |   |   |--- value: [3005.00]
# |   |   |   |   |   |--- feature_9 >  3100.00
# |   |   |   |   |   |   |--- feature_2 <= 524.50
# |   |   |   |   |   |   |   |--- feature_2 <= 472.50
# |   |   |   |   |   |   |   |   |--- value: [2880.00]
# |   |   |   |   |   |   |   |--- feature_2 >  472.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 171.50
# |   |   |   |   |   |   |   |   |   |--- value: [2859.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  171.50
# |   |   |   |   |   |   |   |   |   |--- value: [2858.00]
# |   |   |   |   |   |   |--- feature_2 >  524.50
# |   |   |   |   |   |   |   |--- value: [2938.00]
# |   |   |--- feature_6 >  5.00
# |   |   |   |--- feature_1 <= 5.60
# |   |   |   |   |--- feature_1 <= 5.48
# |   |   |   |   |   |--- feature_0 <= 167.90
# |   |   |   |   |   |   |--- value: [3837.00]
# |   |   |   |   |   |--- feature_0 >  167.90
# |   |   |   |   |   |   |--- feature_1 <= 5.31
# |   |   |   |   |   |   |   |--- value: [3658.00]
# |   |   |   |   |   |   |--- feature_1 >  5.31
# |   |   |   |   |   |   |   |--- value: [3551.00]
# |   |   |   |   |--- feature_1 >  5.48
# |   |   |   |   |   |--- feature_4 <= 1.93
# |   |   |   |   |   |   |--- value: [3055.00]
# |   |   |   |   |   |--- feature_4 >  1.93
# |   |   |   |   |   |   |--- value: [3211.00]
# |   |   |   |--- feature_1 >  5.60
# |   |   |   |   |--- value: [4361.00]

# %%
features = list(X.columns[0:])
features
# Out:
# ['peso',
#  'resolución',
#  'densidad_pixel',
#  'nucleos_cpu',
#  'frec_cpu',
#  'mem_interna',
#  'ram',
#  'camara_tras',
#  'camara_frontal',
#  'bateria',
#  'ancho']

# %%
y1 = df[['precio']]
target = list(y1.columns[0:])
target
# Out:
# ['precio']

# %%
fig = plt.figure(figsize=(25,20))
_= tree.plot_tree(model, feature_names=features, class_names=target, filled=True)
