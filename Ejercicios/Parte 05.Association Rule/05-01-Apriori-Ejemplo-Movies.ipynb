# %% [markdown]
# # Apriori - Ejemplo - Movies

# %% [markdown]
# **Contexto**
# Este conjunto de datos ficticio, con una lista de películas asociadad de manera aleatoria.
#
# **Contenido**
# Contiene 7501 renglones y 20 columnas, una por película.
#
# **Planteamiento del problema**
# Se busca encontrar las asociaciones de películas que pudieran recomendarse al mismo tiempo.

# %%
# Importar librerias
import pandas as pd

from apyori import apriori

# %% [markdown]
# ## Cargar Datos

# %%
# Importar los datos
df = pd.read_csv('movie_dataset.csv', header=None)
df.head()
# Out:
#               0         1                   2                          3   \
# 0   The Revenant  13 Hours              Allied                   Zootopia
# 1         Beirut   Martian             Get Out                        NaN
# 2       Deadpool       NaN                 NaN                        NaN
# 3          X-Men    Allied                 NaN                        NaN
# 4  Ninja Turtles     Moana  Ghost in the Shell  Ralph Breaks the Internet
#
#           4         5       6                 7             8          9   \
# 0     Jigsaw  Achorman  Grinch  Fast and Furious  Ghostbusters  Wolverine
# 1        NaN       NaN     NaN               NaN           NaN        NaN
# 2        NaN       NaN     NaN               NaN           NaN        NaN
# 3        NaN       NaN     NaN               NaN           NaN        NaN
# 4  John Wick       NaN     NaN               NaN           NaN        NaN
#
#         10         11          12                 13             14  \
# 0  Mad Max  John Wick  La La Land  The Good Dunosaur  Ninja Turtles
# 1      NaN        NaN         NaN                NaN            NaN
# 2      NaN        NaN         NaN                NaN            NaN
# 3      NaN        NaN         NaN                NaN            NaN
# 4      NaN        NaN         NaN                NaN            NaN
#
#                            15      16          17        18           19
# 0  The Good Dunosaur Bad Moms  2 Guns  Inside Out  Valerian  Spiderman 3
# 1                         NaN     NaN         NaN       NaN          NaN
# 2                         NaN     NaN         NaN       NaN          NaN
# 3                         NaN     NaN         NaN       NaN          NaN
# 4                         NaN     NaN         NaN       NaN          NaN

# %% [markdown]
# ## EDA

# %%
# Revisar los datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   object
#  1   1       5747 non-null   object
#  2   2       4389 non-null   object
#  3   3       3345 non-null   object
#  4   4       2529 non-null   object
#  5   5       1864 non-null   object
#  6   6       1369 non-null   object
#  7   7       981 non-null    object
#  8   8       654 non-null    object
#  9   9       395 non-null    object
#  10  10      256 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Modelado

# %%
# Transformar cataframe para uso del algoritmo
transactions = []
for i in range(0, 7501):
    transactions.append([str(df.values[i, j]) for j in range(0,20)])

# %%
# Entrenamiento
model = apriori(transactions, min_support = 0.003 , min_confidence = 0.3,
                min_lift = 3, min_length = 2)

# %% [markdown]
# ## Visualizacion

# %%
# Resultados
results = list(model)

# %%
def inspect(results):
    rh          = [tuple(result[2][0][0]) for result in results]
    lh          = [tuple(result[2][0][1]) for result in results]
    support     = [result[1] for result in results]
    confidence  = [result[2][0][2] for result in results]
    lift        = [result[2][0][3] for result in results]
    return list(zip(rh, lh, support, confidence, lift))

# %%
# Convierte a dataframe para ver los resultados
resultdf = pd.DataFrame(inspect(results),
           columns=['rhs','lhs','support','confidence','lift'])

# %%
resultdf
# Out:
#                                            rhs                          lhs  \
# 0                               (Red Sparrow,)             (Green Lantern,)
# 1                                 (Star Wars,)             (Green Lantern,)
# 2                             (Kung Fu Panda,)                   (Jumanji,)
# 3                              (Wonder Woman,)                   (Jumanji,)
# 4                                 (Star Wars,)              (The Revenant,)
# ..                                         ...                          ...
# 97              (Intern, Ninja Turtles, Moana)           (nan, Spiderman 3)
# 98                              (Intern, Thor)  (nan, Ninja Turtles, Moana)
# 99   (Ninja Turtles, The Revenant, Tomb Rider)                (Intern, nan)
# 100       (Intern, Ninja Turtles, World War Z)            (nan, Tomb Rider)
# 101      (Ninja Turtles, Jumanji, World War Z)            (nan, Tomb Rider)
#
#       support  confidence      lift
# 0    0.005733    0.300699  3.790833
# 1    0.005866    0.372881  4.700812
# 2    0.015998    0.323450  3.291994
# 3    0.005333    0.377358  3.840659
# 4    0.005066    0.322034  4.506672
# ..        ...         ...       ...
# 97   0.003333    0.301205  4.582834
# 98   0.003066    0.383333  7.987176
# 99   0.003333    0.390625  4.098011
# 100  0.003066    0.522727  3.002280
# 101  0.003066    0.560976  3.221959
#
# [102 rows x 5 columns]

# %%
resultdf.sort_values(by = ['support'],axis=0,ascending=False).head(30)
# Out:
#                                     rhs                   lhs   support  \
# 2                      (Kung Fu Panda,)            (Jumanji,)  0.015998
# 28                     (Kung Fu Panda,)        (nan, Jumanji)  0.015998
# 62                 (Intern, Tomb Rider)        (nan, Jumanji)  0.008666
# 18                 (Intern, Tomb Rider)            (Jumanji,)  0.008666
# 68        (Ninja Turtles, The Revenant)         (Intern, nan)  0.007199
# 21        (Ninja Turtles, The Revenant)             (Intern,)  0.007199
# 71            (Tomb Rider, World War Z)         (Intern, nan)  0.006666
# 26       (Ninja Turtles, Kung Fu Panda)            (Jumanji,)  0.006666
# 23            (Tomb Rider, World War Z)             (Intern,)  0.006666
# 74       (Ninja Turtles, Kung Fu Panda)        (nan, Jumanji)  0.006666
# 27          (Tomb Rider, Kung Fu Panda)            (Jumanji,)  0.006399
# 75          (Tomb Rider, Kung Fu Panda)        (nan, Jumanji)  0.006399
# 30              (The Revenant, Jumanji)         (Tomb Rider,)  0.005999
# 78              (The Revenant, Jumanji)     (nan, Tomb Rider)  0.005999
# 16                         (Star Wars,)  (nan, Green Lantern)  0.005866
# 1                          (Star Wars,)      (Green Lantern,)  0.005866
# 0                        (Red Sparrow,)      (Green Lantern,)  0.005733
# 15                       (Red Sparrow,)  (nan, Green Lantern)  0.005733
# 72               (Iron Man, Tomb Rider)        (nan, Jumanji)  0.005333
# 24               (Iron Man, Tomb Rider)            (Jumanji,)  0.005333
# 3                       (Wonder Woman,)            (Jumanji,)  0.005333
# 33                      (Wonder Woman,)        (nan, Jumanji)  0.005333
# 4                          (Star Wars,)       (The Revenant,)  0.005066
# 40                         (Star Wars,)   (nan, The Revenant)  0.005066
# 12           (Fantastic Beast, Jumanji)         (Tomb Rider,)  0.004799
# 19                (Intern, Spiderman 3)              (Moana,)  0.004799
# 53           (Fantastic Beast, Jumanji)     (nan, Tomb Rider)  0.004799
# 65                (Intern, Spiderman 3)          (nan, Moana)  0.004799
# 61  (Intern, Ninja Turtles, Tomb Rider)            (Jumanji,)  0.004399
# 39           (Spiderman 3, World War Z)         (Tomb Rider,)  0.004399
#
#     confidence      lift
# 2     0.323450  3.291994
# 28    0.323450  3.291994
# 62    0.311005  3.165328
# 18    0.311005  3.165328
# 68    0.305085  3.200616
# 21    0.305085  3.200616
# 71    0.318471  3.341054
# 26    0.390625  3.975683
# 23    0.318471  3.341054
# 74    0.390625  3.975683
# 27    0.393443  4.004360
# 75    0.393443  4.004360
# 30    0.523256  3.005315
# 78    0.523256  3.005315
# 16    0.372881  4.700812
# 1     0.372881  4.700812
# 0     0.300699  3.790833
# 15    0.300699  3.790833
# 72    0.322581  3.283144
# 24    0.322581  3.283144
# 3     0.377358  3.840659
# 33    0.377358  3.840659
# 4     0.322034  4.506672
# 40    0.322034  4.515096
# 12    0.571429  3.281995
# 19    0.423529  3.268410
# 53    0.571429  3.281995
# 65    0.423529  3.268410
# 61    0.366667  3.731841
# 39    0.611111  3.509912
